# %%
import os,re, sys
from collections import Counter


#for dev only
import pandas as pd

sys.path.append(os.path.abspath('/Users/mq1/IU/csci_b551/bwcooley-mckquinn-a2/part3'))
import SeekTruth

# %%
train_path = '../deceptive.train.txt' 
test_path = '../deceptive.test.txt'
#read in data
train_data = SeekTruth.load_file(train_path)
test_data = SeekTruth.load_file(test_path)

# %%
#check dtypes
print('Train data type: ', type(train_data))
print('Test data type: ', type(test_data))
# Out:
# Train data type:  <class 'dict'>
# Test data type:  <class 'dict'>

# %%
train_data['classes']
# Out:
# ['truthful', 'deceptive']

# %%
# Check counts of labels
label_count = (Counter(train_data['labels']))

# %%
def word_in_dict(word_dict, word):
    '''Check if element in dictionary.
    '''
    if word in word_dict:
        word_dict[word] += 1
    else:
        word_dict[word] = 1
    return word_dict

# %%
def get_clean_text(words):
    clean_sentence = list()
    puncutation = ".,!;?'$)#(/" 
    for word in words:
        word = word.lower()
        word = word.strip(puncutation)
        if word.isalpha():
            clean_sentence.append(word)
    return clean_sentence

# %%
def get_vocab(train_data):
    '''Get vocabulary within trianing data. Assuming words are broken up by
    spaces. No punctuation, caps, and lemmas are taken into account.
    Input: 
        train_data(dict): training data where objects is a string.
    Return: 
        words_dcitionary(dict): words and their count of occurance in data.
        deceptive_words_dict(dict): words and their count of occurance in deceptive labeled data.
        truthful_words_dict(dict): words and their count of occurance in truthful labeled data.
    '''
    words_dictionary = dict()
    deceptive_words_dict = dict()
    truthful_words_dict = dict()
    for sentence in range(len(train_data['objects'])):
        words = train_data['objects'][sentence].split(' ')
        words = get_clean_text(words)
        for w in words: 
            
            #word occurance in dataset
            words_dictionary = word_in_dict(words_dictionary, w)
            #sentence labeled as deceptive
            if train_data['labels'][sentence] == 'deceptive':
                deceptive_words_dict = word_in_dict(deceptive_words_dict, w)
            #sentence labeled as truthful
            else:
                truthful_words_dict = word_in_dict(truthful_words_dict, w)
    class_dict = dict(Counter(train_data['labels']))
    return words_dictionary, truthful_words_dict, deceptive_words_dict, class_dict

# %%
vocab, truth_vocab, decep_vocab, class_dict = get_vocab(train_data)
print('Training data has: ',len(vocab), 'unique words')
print('Training data has: ',len(decep_vocab), 'deceptive unique words')
print('Training data has: ',len(truth_vocab), 'truthful unique words')
# Out:
# Training data has:  7532 unique words
# Training data has:  5086 deceptive unique words
# Training data has:  5552 truthful unique words

# %%
words_in_class = dict()
for word in vocab:
    counter = 0 
    if word in decep_vocab:
        counter += 1
    if word in truth_vocab:
        counter += 1
    words_in_class[word] = counter

# %%
def get_tfidf(class_dict, words_in_class):
    tfidf = dict()
    for word in class_dict:
        count = class_dict[word]
        tfidf[word] = words_in_class[word]/count
    return tfidf

# %%
tfidf_truthful = get_tfidf(truth_vocab, words_in_class)

# %%
tfidf_truthful
# Out:
# {'we': 0.0015174506828528073,
#  'stayed': 0.00749063670411985,
#  'for': 0.0017825311942959,
#  'a': 0.0007945967421533572,
#  'one': 0.00819672131147541,
#  'night': 0.009569377990430622,
#  'getaway': 0.15384615384615385,
#  'with': 0.0030816640986132513,
#  'family': 0.047619047619047616,
#  'on': 0.00291970802919708,
#  'thursday': 0.4,
#  'triple': 1.0,
#  'aaa': 0.6666666666666666,
#  'rate': 0.02857142857142857,
#  'of': 0.0017316017316017316,
#  'was': 0.0010111223458038423,
#  'steal': 0.5,
#  'floor': 0.014184397163120567,
#  'room': 0.0021008403361344537,
#  'complete': 0.18181818181818182,
#  'plasma': 0.2222222222222222,
#  'tv': 0.0425531914893617,
#  'bose': 0.5,
#  'stereo': 1.0,
#  'voss': 1.0,
#  'and': 0.0006668889629876625,
#  'evian': 0.5,
#  'water': 0.024096385542168676,
#  'gorgeous': 0.18181818181818182,
#  'tub': 0.06060606060606061,
#  'but': 0.0038910505836575876,
#  'fine': 0.09523809523809523,
#  'us': 0.007751937984496124,
#  'concierge': 0.029850746268656716,
#  'very': 0.0035026269702276708,
#  'helpful': 0.01652892561983471,
#  'you': 0.004640371229698376,
#  'cannot': 0.25,
#  'beat': 0.14285714285714285,
#  'this': 0.0030911901081916537,
#  'location': 0.007142857142857143,
#  'only': 0.011428571428571429,
#  'flaw': 1.0,
#  'breakfast': 0.015037593984962405,
#  'pricey': 0.2,
#  'service': 0.007518796992481203,
#  'four': 0.06666666666666667,
#  'kids': 0.11764705882352941,
#  'adults': 0.5,
#  'friday': 0.4,
#  'morning': 0.02531645569620253,
#  'even': 0.013422818791946308,
#  'though': 0.037037037037037035,
#  'there': 0.005063291139240506,
#  'were': 0.0029542097488921715,
#  'two': 0.014705882352941176,
#  'other': 0.014925373134328358,
#  'tables': 0.5,
#  'in': 0.0014760147601476014,
#  'the': 0.0003459609064175748,
#  'restaurant': 0.02247191011235955,
#  'food': 0.030303030303030304,
#  'good': 0.010869565217391304,
#  'so': 0.006289308176100629,
#  'it': 0.0023148148148148147,
#  'worth': 0.05128205128205128,
#  'wait': 0.04878048780487805,
#  'i': 0.0012307692307692308,
#  'would': 0.006230529595015576,
#  'return': 0.05,
#  'heartbeat': 1.0,
#  'gem': 0.2,
#  'chicago': 0.005128205128205128,
#  'upgrade': 0.08333333333333333,
#  'to': 0.0008988764044943821,
#  'view': 0.015873015873015872,
#  'less': 0.09523809523809523,
#  'than': 0.01818181818181818,
#  'which': 0.011834319526627219,
#  'also': 0.011976047904191617,
#  'included': 0.09523809523809523,
#  'vouchers': 0.25,
#  'had': 0.003683241252302026,
#  'great': 0.0041928721174004195,
#  'river': 0.034482758620689655,
#  'lake': 0.05128205128205128,
#  'wrigley': 0.2,
#  'bldg': 0.5,
#  'tribune': 0.14285714285714285,
#  'most': 0.03508771929824561,
#  'major': 0.2,
#  'restaurants': 0.03333333333333333,
#  'shopping': 0.02531645569620253,
#  'sightseeing': 0.2222222222222222,
#  'attractions': 0.125,
#  'within': 0.03773584905660377,
#  'walking': 0.02666666666666667,
#  'distance': 0.03773584905660377,
#  'large': 0.022222222222222223,
#  'comfortable': 0.013793103448275862,
#  'bed': 0.010309278350515464,
#  'comes': 0.25,
#  'little': 0.02857142857142857,
#  'late': 0.058823529411764705,
#  'as': 0.006024096385542169,
#  'finally': 0.07407407407407407,
#  'catching': 0.5,
#  'up': 0.010471204188481676,
#  'my': 0.003795066413662239,
#  'reviews': 0.03333333333333333,
#  'from': 0.004629629629629629,
#  'past': 0.14285714285714285,
#  'several': 0.058823529411764705,
#  'dear': 0.3333333333333333,
#  'friend': 0.11764705882352941,
#  'at': 0.002570694087403599,
#  'hyatt': 0.058823529411764705,
#  'regency': 0.3333333333333333,
#  'october': 0.3333333333333333,
#  'while': 0.03076923076923077,
#  'visiting': 0.15384615384615385,
#  'her': 0.05263157894736842,
#  'husband': 0.047619047619047616,
#  'out': 0.009950248756218905,
#  'town': 0.06666666666666667,
#  'hotel': 0.0018365472910927456,
#  'is': 0.002157497303128371,
#  'perfect': 0.03278688524590164,
#  'imo': 1.0,
#  'easy': 0.05,
#  'check': 0.024096385542168676,
#  'lovely': 0.058823529411764705,
#  'clean': 0.010752688172043012,
#  'rooms': 0.00819672131147541,
#  'views': 0.05405405405405406,
#  'city': 0.021052631578947368,
#  'know': 0.05555555555555555,
#  'area': 0.02,
#  'pretty': 0.07142857142857142,
#  'well': 0.014814814814814815,
#  'convenient': 0.07407407407407407,
#  'many': 0.025974025974025976,
#  'downtown': 0.029411764705882353,
#  'dinner': 0.047619047619047616,
#  'went': 0.03076923076923077,
#  'clubing': 1.0,
#  'our': 0.004073319755600814,
#  'friends': 0.07407407407407407,
#  'around': 0.030303030303030304,
#  'division': 0.25,
#  'st': 0.2857142857142857,
#  'no': 0.008695652173913044,
#  'problems': 0.08,
#  'getting': 0.06896551724137931,
#  'cabs': 0.4,
#  'back': 0.014814814814814815,
#  'forth': 0.5,
#  'public': 0.125,
#  'transportation': 0.16666666666666666,
#  'right': 0.024096385542168676,
#  'near': 0.06666666666666667,
#  'by': 0.013157894736842105,
#  'bother': 0.2222222222222222,
#  'since': 0.0392156862745098,
#  'needed': 0.07142857142857142,
#  'parking': 0.03225806451612903,
#  'usual': 0.2857142857142857,
#  'expensive': 0.0625,
#  'able': 0.046511627906976744,
#  'get': 0.010362694300518135,
#  'car': 0.05714285714285714,
#  'quickly': 0.125,
#  'however': 0.04081632653061224,
#  'left': 0.0392156862745098,
#  'sunday': 0.16666666666666666,
#  'not': 0.003745318352059925,
#  'exactly': 0.2857142857142857,
#  'high': 0.05,
#  'traffic': 0.2857142857142857,
#  'time': 0.013071895424836602,
#  'although': 0.05714285714285714,
#  'bears': 0.6666666666666666,
#  'homegame': 1.0,
#  'day': 0.015625,
#  'bit': 0.031746031746031744,
#  'busier': 1.0,
#  'think': 0.04,
#  'all': 0.006493506493506494,
#  'best': 0.022988505747126436,
#  'part': 0.06060606060606061,
#  'that': 0.0030864197530864196,
#  'got': 0.01282051282051282,
#  'through': 0.03571428571428571,
#  'hotwire': 0.07142857142857142,
#  'downright': 1.0,
#  'quality': 0.05405405405405406,
#  'omni': 0.047619047619047616,
#  'really': 0.017241379310344827,
#  'delivers': 1.0,
#  'fronts': 1.0,
#  'spaciousness': 1.0,
#  'staff': 0.005952380952380952,
#  'prized': 1.0,
#  'michigan': 0.01680672268907563,
#  'avenue': 0.05128205128205128,
#  'address': 0.6666666666666666,
#  'requires': 2.0,
#  'level': 0.1,
#  'myself': 0.18181818181818182,
#  'whole': 0.1111111111111111,
#  'group': 0.18181818181818182,
#  'people': 0.02631578947368421,
#  'me': 0.009523809523809525,
#  'under': 0.08,
#  'minutes': 0.03278688524590164,
#  'plentiful': 0.3333333333333333,
#  'recommendations': 0.2857142857142857,
#  'dining': 0.14285714285714285,
#  'events': 0.5,
#  'are': 0.006802721088435374,
#  'some': 0.015267175572519083,
#  'largest': 0.2,
#  'find': 0.03773584905660377,
#  'price': 0.022988505747126436,
#  'range': 0.6666666666666666,
#  'standard': 0.13333333333333333,
#  'has': 0.01694915254237288,
#  'separate': 0.10526315789473684,
#  'living': 0.15384615384615385,
#  'work': 0.041666666666666664,
#  'desk': 0.011235955056179775,
#  'fitness': 0.125,
#  'center': 0.08333333333333333,
#  'free': 0.018018018018018018,
#  'weights': 0.5,
#  'weight': 2.0,
#  'machines': 0.2857142857142857,
#  'rows': 0.5,
#  'cardio': 1.0,
#  'equipment': 0.4,
#  'shared': 0.4,
#  'others': 0.09523809523809523,
#  'did': 0.0136986301369863,
#  'feel': 0.044444444444444446,
#  'cramped': 0.3333333333333333,
#  'any': 0.027777777777777776,
#  'way': 0.029850746268656716,
#  'property': 0.08,
#  'asked': 0.029411764705882353,
#  'away': 0.028985507246376812,
#  'elevator': 0.05714285714285714,
#  'what': 0.015873015873015872,
#  'pleasantly': 0.2857142857142857,
#  'decorated': 0.10526315789473684,
#  'functional': 2.0,
#  'need': 0.03278688524590164,
#  'lot': 0.045454545454545456,
#  'when': 0.007722007722007722,
#  'they': 0.00423728813559322,
#  'pleasant': 0.07692307692307693,
#  'prompt': 0.3333333333333333,
#  'used': 0.04878048780487805,
#  'equipped': 0.4,
#  'everything': 0.02247191011235955,
#  'working': 0.1,
#  'order': 0.1111111111111111,
#  'end': 0.07407407407407407,
#  'district': 0.4,
#  'following': 0.2857142857142857,
#  'business': 0.021505376344086023,
#  'meeting': 0.14285714285714285,
#  'another': 0.028169014084507043,
#  'completely': 0.13333333333333333,
#  'impressed': 0.07142857142857142,
#  'personnel': 0.3333333333333333,
#  'during': 0.047619047619047616,
#  'stay': 0.0045045045045045045,
#  'absolutely': 0.07407407407407407,
#  'outstanding': 0.25,
#  'checked': 0.041666666666666664,
#  'quite': 0.03333333333333333,
#  'early': 0.0625,
#  'problem': 0.05405405405405406,
#  'efficiently': 2.0,
#  'somewhat': 0.2857142857142857,
#  'heavy': 0.5,
#  'scent': 2.0,
#  'air': 0.1111111111111111,
#  'freshener': 2.0,
#  'negative': 0.13333333333333333,
#  'entire': 0.09090909090909091,
#  'managed': 0.6666666666666666,
#  'reasonably': 0.5,
#  'opening': 0.25,
#  'windows': 0.07692307692307693,
#  'generally': 0.25,
#  'require': 1.0,
#  'much': 0.025,
#  'stays': 0.2857142857142857,
#  'suffice': 1.0,
#  'say': 0.024390243902439025,
#  'doorman': 0.11764705882352941,
#  'housekeeping': 0.07407407407407407,
#  'manager': 0.06060606060606061,
#  'bartender': 0.3333333333333333,
#  'waiter': 0.5,
#  'amazing': 0.058823529411764705,
#  'never': 0.01834862385321101,
#  'waited': 0.13333333333333333,
#  'more': 0.019230769230769232,
#  'about': 0.01015228426395939,
#  'seconds': 2.0,
#  'anything': 0.058823529411764705,
#  'comfy': 0.09523809523809523,
#  'amenities': 0.06896551724137931,
#  'superior': 0.6666666666666666,
#  'tiny': 0.1111111111111111,
#  'complaint': 0.125,
#  'wastebasket': 0.3333333333333333,
#  'sink': 0.18181818181818182,
#  'or': 0.01282051282051282,
#  'wet': 0.2857142857142857,
#  'bar': 0.021739130434782608,
#  'walk': 0.023809523809523808,
#  'bathroom': 0.013245033112582781,
#  'sitting': 0.2222222222222222,
#  'dispose': 1.0,
#  'paraphernalia': 1.0,
#  'make': 0.044444444444444446,
#  'difference': 0.3333333333333333,
#  'said': 0.02702702702702703,
#  'thanks': 0.18181818181818182,
#  'conrad': 0.05405405405405406,
#  'nights': 0.0196078431372549,
#  'just': 0.00975609756097561,
#  'before': 0.028985507246376812,
#  'thanksgiving': 0.5,
#  'corner': 0.06896551724137931,
#  'overlooking': 0.4,
#  'n': 0.125,
#  'av': 0.3333333333333333,
#  'building': 0.05405405405405406,
#  'star': 0.05405405405405406,
#  'damn': 0.3333333333333333,
#  'place': 0.018518518518518517,
#  'faint': 2.0,
#  'praise': 1.0,
#  'wonderful': 0.024691358024691357,
#  'unbelievably': 2.0,
#  'superb': 0.11764705882352941,
#  'hd': 1.0,
#  'screens': 1.0,
#  'luxury': 0.3333333333333333,
#  'bedlinens': 1.0,
#  'ipod': 0.2222222222222222,
#  'radio': 0.5,
#  'huge': 0.03773584905660377,
#  'unbeatable': 0.6666666666666666,
#  'heart': 0.2,
#  'watched': 0.5,
#  'light': 0.15384615384615385,
#  'festival': 0.25,
#  'parade': 0.5,
#  'window': 0.07407407407407407,
#  'breakfasts': 0.16666666666666666,
#  'excellent': 0.019801980198019802,
#  'help': 0.07692307692307693,
#  'yourself': 0.3333333333333333,
#  'buffet': 0.07142857142857142,
#  'here': 0.010638297872340425,
#  'full': 0.04878048780487805,
#  'attentive': 0.125,
#  'table': 0.15384615384615385,
#  'have': 0.004705882352941176,
#  'hesitation': 0.16666666666666666,
#  'recommending': 2.0,
#  'staying': 0.03333333333333333,
#  'again': 0.010362694300518135,
#  'days': 0.04878048780487805,
#  'girlfriends': 0.4,
#  'first': 0.01904761904761905,
#  'because': 0.020202020202020204,
#  'saw': 0.07142857142857142,
#  'travelzoo': 0.1111111111111111,
#  'three': 0.05555555555555555,
#  'year': 0.05263157894736842,
#  'olds': 0.3333333333333333,
#  'suite': 0.02702702702702703,
#  'double': 0.08,
#  'beds': 0.024390243902439025,
#  'pull': 0.25,
#  'sofa': 0.2,
#  'plenty': 0.1,
#  'everone': 1.0,
#  'came': 0.03571428571428571,
#  'into': 0.043478260869565216,
#  'contact': 0.25,
#  'delivery': 0.5,
#  'coffee': 0.02857142857142857,
#  'juice': 0.2222222222222222,
#  'hot': 0.04878048780487805,
#  'chocolate': 0.16666666666666666,
#  'fabulous': 0.08,
#  'where': 0.03636363636363636,
#  'eat': 0.07692307692307693,
#  'movies': 1.0,
#  'areas': 0.08695652173913043,
#  'etc': 0.05263157894736842,
#  'mention': 0.2222222222222222,
#  'simply': 0.1111111111111111,
#  'decided': 0.05714285714285714,
#  'new': 0.046511627906976744,
#  'favorite': 0.15384615384615385,
#  'arrived': 0.029411764705882353,
#  'september': 0.5,
#  'took': 0.034482758620689655,
#  'ill': 2.0,
#  'plane': 1.0,
#  'after': 0.016129032258064516,
#  'travelling': 0.4,
#  'manchester': 1.0,
#  'anticipated': 1.0,
#  'go': 0.018518518518518517,
#  'spacious': 0.03389830508474576,
#  'extremely': 0.04081632653061224,
#  'could': 0.013157894736842105,
#  'ask': 0.1111111111111111,
#  'outside': 0.07692307692307693,
#  'door': 0.02666666666666667,
#  'every': 0.029411764705882353,
#  'requested': 0.06451612903225806,
#  'see': 0.046511627906976744,
#  'sun': 0.6666666666666666,
#  'terrace': 0.2857142857142857,
#  'gym': 0.07692307692307693,
#  'having': 0.05405405405405406,
#  'idea': 0.25,
#  'grim': 1.0,
#  'few': 0.03333333333333333,
#  'sunbeds': 1.0,
#  'concrete': 0.4,
#  'noise': 0.044444444444444446,
#  'an': 0.009478672985781991,
#  'conditioning': 0.6666666666666666,
#  'unit': 0.5,
#  'do': 0.021505376344086023,
#  'cheering': 1.0,
#  'pleasing': 0.5,
#  'something': 0.08,
#  'everyone': 0.058823529411764705,
#  'yes': 0.09090909090909091,
#  'visit': 0.0625,
#  'chose': 0.10526315789473684,
#  'due': 0.11764705882352941,
#  'its': 0.034482758620689655,
#  'such': 0.05128205128205128,
#  'sears': 0.4,
#  'tower': 0.05,
#  'magnificent': 0.05128205128205128,
#  'mile': 0.03225806451612903,
#  'parks': 0.5,
#  'subway': 0.09090909090909091,
#  'bus': 0.18181818181818182,
#  'stops': 0.16666666666666666,
#  'close': 0.03225806451612903,
#  'travel': 0.05,
#  'locations': 0.2857142857142857,
#  'overall': 0.043478260869565216,
#  'nice': 0.009615384615384616,
#  'safe': 0.16666666666666666,
#  'beautiful': 0.02702702702702703,
#  'field': 0.25,
#  'soldier': 0.3333333333333333,
#  'both': 0.03125,
#  'teams': 0.5,
#  'play': 0.6666666666666666,
#  'love': 0.058823529411764705,
#  'defenitely': 1.0,
#  'fairmont': 0.05128205128205128,
#  'frequent': 0.2222222222222222,
#  'traveler': 0.2222222222222222,
#  'am': 0.028985507246376812,
#  'familiar': 2.0,
#  'rituals': 1.0,
#  'almost': 0.09090909090909091,
#  'flight': 0.3333333333333333,
#  'cancellations': 1.0,
#  'home': 0.05,
#  'airport': 0.1,
#  'atlanta': 1.0,
#  'shuttle': 0.2857142857142857,
#  'option': 0.4,
#  'lieu': 1.0,
#  'over': 0.023809523809523808,
#  'priced': 0.4,
#  'taxis': 0.5,
#  'upon': 0.06451612903225806,
#  'arrival': 0.11764705882352941,
#  'immediately': 0.10526315789473684,
#  'noticed': 0.2,
#  'entrance': 0.16666666666666666,
#  'appeared': 0.16666666666666666,
#  'welcoming': 0.16666666666666666,
#  'warm': 0.10526315789473684,
#  'person': 0.08,
#  'if': 0.009523809523809525,
#  'prefer': 0.3333333333333333,
#  'king': 0.037037037037037035,
#  'reconfirming': 1.0,
#  'reservation': 0.03225806451612903,
#  'preference': 0.3333333333333333,
#  'always': 0.03571428571428571,
#  'take': 0.031746031746031744,
#  'can': 0.019801980198019802,
#  'fantastic': 0.047619047619047616,
#  'suited': 2.0,
#  'linen': 0.5,
#  'these': 0.06451612903225806,
#  'incredible': 0.16666666666666666,
#  'down': 0.022988505747126436,
#  'feather': 1.0,
#  'pillows': 0.05555555555555555,
#  'named': 0.4,
#  'encompass': 1.0,
#  'made': 0.022988505747126436,
#  'pillow': 0.3333333333333333,
#  'factory': 0.25,
#  'tags': 1.0,
#  'plan': 0.2,
#  'buy': 0.5,
#  'ate': 0.125,
#  'aria': 0.2857142857142857,
#  'like': 0.012987012987012988,
#  'be': 0.006734006734006734,
#  'considered': 0.6666666666666666,
#  'does': 0.10526315789473684,
#  'stand': 0.3333333333333333,
#  'own': 0.16666666666666666,
#  'asian': 1.0,
#  'fusion': 1.0,
#  'truly': 0.125,
#  'gourmand': 1.0,
#  'foodie': 1.0,
#  'appreciate': 0.5,
#  'taste': 0.2857142857142857,
#  'drawback': 1.0,
#  'seems': 0.125,
#  'stick': 2.0,
#  'their': 0.019801980198019802,
#  'theme': 0.5,
#  'solely': 1.0,
#  'missed': 0.4,
#  'mark': 1.0,
#  'relatively': 1.0,
#  'things': 0.06666666666666667,
#  'scrambled': 2.0,
#  'eggs': 0.4,
#  'tasted': 0.5,
#  'metallic': 1.0,
#  'special': 0.08695652173913043,
#  'passed': 0.6666666666666666,
#  'highly': 0.0425531914893617,
#  'recommend': 0.02,
#  'atmosphere': 0.15384615384615385,
#  'pass': 0.2857142857142857,
#  'ok': 0.09523809523809523,
#  'trip': 0.0273972602739726,
#  'litlle': 1.0,
#  'worried': 0.5,
#  'wath': 1.0,
#  'experience': 0.025,
#  'booked': 0.018691588785046728,
#  'deluxe': 0.5,
#  'coplaint': 1.0,
#  'bath': 0.10526315789473684,
#  'appliances': 2.0,
#  'size': 0.05,
#  'internet': 0.029411764705882353,
#  'breaksfast': 1.0,
#  'aroufn': 1.0,
#  'surprise': 0.16666666666666666,
#  'locating': 2.0,
#  'blocks': 0.0392156862745098,
#  'quiet': 0.03773584905660377,
#  'ready': 0.08,
#  'mind': 0.2222222222222222,
#  'until': 0.07142857142857142,
#  'priceline': 0.022727272727272728,
#  'per': 0.0625,
#  'upgraded': 0.07407407407407407,
#  'blown': 0.4,
#  'forgot': 0.4,
#  'thank': 0.15384615384615385,
#  'them': 0.028169014084507043,
#  'fridge': 0.0625,
#  'sized': 0.15384615384615385,
#  'closet': 0.2222222222222222,
#  'hangers': 1.0,
#  'knew': 0.15384615384615385,
#  'previous': 0.15384615384615385,
#  'touch': 0.125,
#  'employee': 0.15384615384615385,
#  'friendly': 0.013605442176870748,
#  'east': 0.08695652173913043,
#  'hear': 0.07142857142857142,
#  'hallways': 0.16666666666666666,
#  'rude': 0.07407407407407407,
#  'yelling': 0.6666666666666666,
#  'children': 0.5,
#  'why': 0.07142857142857142,
#  'complains': 1.0,
#  'charged': 0.08333333333333333,
#  'without': 0.05263157894736842,
#  'privledges': 1.0,
#  'use': 0.03773584905660377,
#  'health': 0.3333333333333333,
#  'club': 0.10526315789473684,
#  'tried': 0.11764705882352941,
#  'bakery': 0.6666666666666666,
#  'too': 0.02666666666666667,
#  'crowded': 0.4,
#  'nearby': 0.1,
#  'grocery': 0.5,
#  'store': 0.2,
#  'behind': 0.16666666666666666,
#  'far': 0.07407407407407407,
#  'bad': 0.045454545454545456,
#  'big': 0.038461538461538464,
#  'want': 0.03636363636363636,
#  'busy': 0.125,
#  'lobby': 0.015267175572519083,
#  'plus': 0.09523809523809523,
#  'loved': 0.03333333333333333,
#  'anyone': 0.08,
#  'wife': 0.0425531914893617,
#  'spend': 0.16666666666666666,
#  'weekend': 0.024691358024691357,
#  'found': 0.03076923076923077,
#  'located': 0.05405405405405406,
#  'lost': 0.16666666666666666,
#  'convention': 0.125,
#  'world': 0.3333333333333333,
#  'feeling': 0.16666666666666666,
#  'larger': 0.15384615384615385,
#  'hotels': 0.018018018018018018,
#  'professional': 0.15384615384615385,
#  'making': 0.11764705882352941,
#  'review': 0.14285714285714285,
#  'off': 0.02631578947368421,
#  'hard': 0.043478260869565216,
#  'paid': 0.03571428571428571,
#  'impression': 0.2857142857142857,
#  'sliding': 0.5,
#  'doors': 0.2,
#  'wow': 0.25,
#  'upscale': 0.25,
#  'mall': 0.09090909090909091,
#  'type': 0.25,
#  'look': 0.06060606060606061,
#  'open': 0.05263157894736842,
#  'watch': 0.4,
#  'fountains': 1.0,
#  'escalator': 1.0,
#  'let': 0.07692307692307693,
#  'suggest': 0.5,
#  'call': 0.03571428571428571,
#  'ahead': 0.3333333333333333,
#  'coming': 0.1111111111111111,
#  'women': 1.0,
#  'higher': 0.18181818181818182,
#  'she': 0.030303030303030304,
#  'happy': 0.09090909090909091,
#  'told': 0.024691358024691357,
#  'veiw': 1.0,
#  'thought': 0.0625,
#  'give': 0.06896551724137931,
#  'information': 0.2857142857142857,
#  'wouldnt': 0.5,
#  'stuck': 0.3333333333333333,
#  'wall': 0.09523809523809523,
#  'doubles': 0.25,
#  'alarm': 0.5,
#  'clock': 1.0,
#  'century': 0.5,
#  'plug': 0.5,
#  'your': 0.021052631578947368,
#  'listen': 0.5,
#  'music': 0.1111111111111111,
#  'relaxing': 0.2,
#  'long': 0.044444444444444446,
#  'touring': 0.6666666666666666,
#  'spotless': 0.25,
#  'toiletries': 0.2857142857142857,
#  'feature': 0.4,
#  'computers': 0.6666666666666666,
#  'gives': 1.0,
#  'access': 0.058823529411764705,
#  'printing': 0.3333333333333333,
#  'boarding': 0.16666666666666666,
#  'screen': 0.08333333333333333,
#  'click': 1.0,
#  'airline': 0.5,
#  'icon': 1.0,
#  'instructions': 1.0,
#  'passes': 0.25,
#  'minute': 0.0625,
#  'handy': 0.2857142857142857,
#  'ohare': 0.5,
#  'skip': 2.0,
#  'line': 0.04878048780487805,
#  'frustrated': 0.4,
#  'passengers': 0.5,
#  'better': 0.024390243902439025,
#  'experiences': 0.3333333333333333,
#  'alot': 0.6666666666666666,
#  'definitely': 0.028169014084507043,
#  'choice': 0.07142857142857142,
#  'families': 0.3333333333333333,
#  'couples': 0.6666666666666666,
#  'im': 0.5,
#  'passing': 0.6666666666666666,
#  'including': 0.07142857142857142,
#  'luxurious': 0.16666666666666666,
#  'complimentary': 0.06451612903225806,
#  'hilton': 0.06666666666666667,
#  'honors': 0.3333333333333333,
#  'members': 0.2222222222222222,
#  'connected': 0.5,
#  'imagine': 0.5,
#  'asset': 1.0,
#  'winter': 0.4,
#  'next': 0.018518518518518517,
#  'will': 0.0125,
#  'sure': 0.045454545454545456,
#  'reunion': 0.5,
#  'bottled': 0.25,
#  'breeze': 0.4,
#  'hours': 0.08333333333333333,
#  'please': 0.18181818181818182,
#  'standards': 0.3333333333333333,
#  'aesthetically': 1.0,
#  'date': 1.0,
#  'attached': 0.1,
#  'nordstrom': 0.3333333333333333,
#  'northbridge': 1.0,
#  'boyfriend': 0.25,
#  'anniversary': 0.15384615384615385,
#  'second': 0.04878048780487805,
#  'walked': 0.06451612903225806,
#  'won': 0.5,
#  'white': 0.16666666666666666,
#  'luxurous': 1.0,
#  'bedding': 0.15384615384615385,
#  'subroofer': 1.0,
#  'surround': 2.0,
#  'sound': 0.16666666666666666,
#  'speakers': 0.5,
#  'reminded': 0.6666666666666666,
#  'him': 0.1111111111111111,
#  'come': 0.06896551724137931,
#  'w': 0.2222222222222222,
#  'shower': 0.028169014084507043,
#  'granite': 1.0,
#  'countertops': 0.5,
#  'his': 0.0625,
#  'robes': 0.2,
#  'slippers': 0.25,
#  'enough': 0.05,
#  'side': 0.08,
#  'means': 0.3333333333333333,
#  'prefect': 1.0,
#  'amount': 0.25,
#  'actually': 0.09090909090909091,
#  'going': 0.0392156862745098,
#  'usually': 0.2857142857142857,
#  'closer': 0.25,
#  'mid': 0.6666666666666666,
#  'none': 0.3333333333333333,
#  'ever': 0.038461538461538464,
#  'deal': 0.03773584905660377,
#  'pacage': 1.0,
#  'nicest': 0.5,
#  'dozen': 0.6666666666666666,
#  'trips': 0.25,
#  'suites': 0.09090909090909091,
#  'extras': 0.5,
#  'turn': 0.14285714285714285,
#  'beverages': 0.5,
#  'delivered': 0.09523809523809523,
#  'attended': 0.25,
#  'intruded': 1.0,
#  'definately': 0.13333333333333333,
#  'given': 0.058823529411764705,
#  'central': 0.25,
#  'wished': 2.0,
#  'pool': 0.03571428571428571,
#  'felt': 0.05555555555555555,
#  'swims': 1.0,
#  'evening': 0.07142857142857142,
#  'spent': 0.07142857142857142,
#  'recommended': 0.125,
#  'base': 0.3333333333333333,
#  'exploring': 0.6666666666666666,
#  'exhibit': 1.0,
#  'art': 0.07692307692307693,
#  'institute': 0.2222222222222222,
#  'selected': 2.0,
#  'still': 0.03225806451612903,
#  'being': 0.037037037037037035,
#  'renovated': 0.16666666666666666,
#  'uniformly': 0.5,
#  'positive': 0.2,
#  'nicely': 0.25,
#  'newly': 0.6666666666666666,
#  'remodeled': 0.6666666666666666,
#  'immaculate': 0.2857142857142857,
#  'glitch': 2.0,
#  'involved': 0.6666666666666666,
#  'replenished': 1.0,
#  'maid': 0.18181818181818182,
#  'bedtime': 1.0,
#  'called': 0.021739130434782608,
#  'front': 0.014184397163120567,
#  'fresh': 0.09523809523809523,
#  'supply': 0.3333333333333333,
#  'underwhelming': 1.0,
#  'places': 0.08,
#  'probably': 0.1,
#  'eaten': 0.6666666666666666,
#  'different': 0.05405405405405406,
#  'may': 0.07142857142857142,
#  'whenever': 2.0,
#  'phone': 0.037037037037037035,
#  'lower': 0.2857142857142857,
#  'beautifully': 0.4,
#  'appointed': 0.125,
#  'wanted': 0.07407407407407407,
#  'bucks': 0.2857142857142857,
#  'crisp': 1.0,
#  'sheets': 0.125,
#  'flat': 0.1,
#  'carpet': 0.18181818181818182,
#  'short': 0.09090909090909091,
#  'prepared': 0.25,
#  'pay': 0.0625,
#  'park': 0.04,
#  'hey': 1.0,
#  'charge': 0.05263157894736842,
#  'bottle': 0.18181818181818182,
#  'normally': 0.3333333333333333,
#  'buck': 2.0,
#  'total': 0.3333333333333333,
#  'nightly': 0.5,
#  'drink': 0.09523809523809523,
#  'travels': 0.5,
#  'fast': 0.2,
#  'amenity': 0.5,
#  'imaginable': 1.0,
#  'money': 0.05263157894736842,
#  'exorbitant': 1.0,
#  'absurd': 1.0,
#  'fee': 0.25,
#  'wireless': 0.2,
#  'bored': 1.0,
#  'routine': 1.0,
#  'fare': 0.4,
#  'gourmet': 0.5,
#  'pantry': 0.3333333333333333,
#  'refreshing': 1.0,
#  'change': 0.16666666666666666,
#  'greeted': 0.11764705882352941,
#  'zipped': 1.0,
#  'reception': 0.06060606060606061,
#  'each': 0.05128205128205128,
#  'restful': 1.0,
#  'sleep': 0.07407407407407407,
#  'glass': 0.2222222222222222,
#  'stall': 0.5,
#  'furnished': 0.2,
#  'thru': 0.07692307692307693,
#  'fl': 1.0,
#  'westfield': 1.0,
#  'north': 0.07407407407407407,
#  'bridge': 1.0,
#  'enjoy': 0.11764705882352941,
#  'stores': 0.5,
#  'course': 0.13333333333333333,
#  'steps': 0.3333333333333333,
#  'ave': 0.03333333333333333,
#  'cta': 0.5,
#  'stop': 0.18181818181818182,
#  'grand': 2.0,
#  'red': 0.14285714285714285,
#  'block': 0.0625,
#  'helped': 0.25,
#  'print': 0.25,
#  'frustrating': 0.5,
#  'nowadays': 1.0,
#  'same': 0.05555555555555555,
#  'loud': 0.16666666666666666,
#  'neighbors': 1.0,
#  'liked': 0.11764705882352941,
#  'longer': 0.2,
#  'super': 0.09523809523809523,
#  'system': 0.15384615384615385,
#  'ihome': 2.0,
#  'bring': 0.16666666666666666,
#  'week': 0.05,
#  'pleased': 0.10526315789473684,
#  'described': 1.0,
#  'televison': 1.0,
#  'particularly': 0.2857142857142857,
#  'especially': 0.06896551724137931,
#  'bedside': 0.5,
#  'knowledgeable': 0.5,
#  'satisfactory': 2.0,
#  'overpriced': 0.14285714285714285,
#  'drinks': 0.08,
#  'maintained': 0.4,
#  'treadmills': 1.0,
#  'elipitical': 1.0,
#  'steppers': 1.0,
#  'machine': 0.25,
#  'might': 0.1,
#  'story': 0.25,
#  'dead': 1.0,
#  'minor': 0.18181818181818182,
#  'thing': 0.05,
#  'maker': 0.2,
#  'offered': 0.1111111111111111,
#  'eight': 2.0,
#  'attractive': 0.2857142857142857,
#  'reasonable': 0.13333333333333333,
#  'value': 0.09090909090909091,
#  'wrong': 0.16666666666666666,
#  'contain': 1.0,
#  'amenties': 1.0,
#  'fallen': 0.25,
#  'chain': 0.2,
#  'customer': 0.07407407407407407,
#  'cities': 0.3333333333333333,
#  'been': 0.01904761904761905,
#  'often': 0.2,
#  'smoothly': 2.0,
#  'then': 0.02531645569620253,
#  'changed': 0.2222222222222222,
#  'small': 0.02040816326530612,
#  'indoors': 0.5,
#  'looks': 0.3333333333333333,
#  'website': 0.09090909090909091,
#  'types': 0.5,
#  'saks': 0.5,
#  'nordstroms': 0.3333333333333333,
#  'filenes': 1.0,
#  'basement': 0.2,
#  'macys': 0.3333333333333333,
#  'la': 0.25,
#  'perla': 1.0,
#  'apple': 2.0,
#  'itself': 0.08333333333333333,
#  'tvs': 0.25,
#  'clicked': 1.0,
#  'joining': 0.5,
#  'guest': 0.07692307692307693,
#  'program': 0.2,
#  'email': 0.2857142857142857,
#  'completing': 2.0,
#  'registration': 0.16666666666666666,
#  'terrific': 0.2,
#  'junior': 0.5,
#  'seen': 0.14285714285714285,
#  'excuse': 0.2,
#  'catch': 0.4,
#  'served': 0.16666666666666666,
#  'atrium': 2.0,
#  'top': 0.043478260869565216,
#  'notch': 0.16666666666666666,
#  'waits': 1.0,
#  'empty': 0.5,
#  'shed': 1.0,
#  'aquarium': 0.5,
#  'waste': 0.6666666666666666,
#  'musium': 1.0,
#  'remains': 1.0,
#  'tied': 2.0,
#  'london': 0.3333333333333333,
#  'favourite': 0.3333333333333333,
#  'keep': 0.13333333333333333,
#  'daughter': 0.11764705882352941,
#  'vacations': 2.0,
#  'easily': 0.2,
#  'accessible': 0.4,
#  'daily': 0.25,
#  'cleaning': 0.18181818181818182,
#  'turndown': 0.5,
#  'member': 0.15384615384615385,
#  'encountered': 0.3333333333333333,
#  'kind': 0.1111111111111111,
#  'someone': 0.08695652173913043,
#  'greeting': 0.3333333333333333,
#  ...}

# %%
def get_basic_prob(word, vocab):
    #get probability of occurance in trianing data
    #assuming word occurs in dictionary
    return vocab[word]/sum(vocab.values())

# %%
def get_bayes_components(train_data):
    vocab, truth_vocab, decep_vocab, class_dict = get_vocab(train_data)
    bayes_components = dict()
    for word in vocab:
        probs = list()
        p_of_word = get_basic_prob(word, vocab)
        probs.append(p_of_word)
        try:
            p_word_truth = get_basic_prob(word, truth_vocab)
            probs.append(p_word_truth)
            p_word_decep = get_basic_prob(word, decep_vocab)
            probs.append(p_word_decep)
        except: 
            if len(probs) == 1:
                #put in extremely low probability
                probs.append(.0000000000000001)
                probs.append(.0000000000000001)

            elif len(probs) == 2: 
                #put in extremely low probability
                probs.append(.0000000000000001)
        p_of_truth = get_basic_prob( 'truthful',class_dict)
        probs.append(p_of_truth)
        p_of_decept = get_basic_prob('deceptive',class_dict)
        probs.append(p_of_decept)
        bayes_components[word] = probs

    return bayes_components

# %%
train_data['classes']
# Out:
# ['truthful', 'deceptive']

# %%
bayes_comp = get_bayes_components(train_data)

# %%
test = '06/04/05'
test.isalpha()
# Out:
# False

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/mq1/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
in_data = list()
for sw in stop_words:
    if sw in vocab:
        in_data.append(sw)

# %%
in_data.sort()

# %%
in_data
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'has',
#  'have',
#  'haven',
#  'having',
#  'he',
#  'her',
#  'here',
#  'herself',
#  'him',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'm',
#  'me',
#  'more',
#  'most',
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  's',
#  'same',
#  'she',
#  'should',
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  'we',
#  'were',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  'you',
#  'your',
#  'yours',
#  'yourself']
